# %%
from dolfin import *
import numpy as np
import matplotlib.pyplot as pl
# %matplotlib inline

parameters["form_compiler"]["optimize"]     = True
parameters["form_compiler"]["cpp_optimize"] = True

# %% [markdown]
# # Problem data
#
# Most of this is ignored for now.

# %%
class InitialInPlaneDisplacements(Expression):     
    def eval(self, values, x):
        values[0] = 0.0
        values[1] = -x[1]/10.0
    def value_shape(self):
        return (2,)

class InitialOutOfPlaneDisplacements(Expression):
    def eval(self, values, x):
        #values[0] = 0.5*x[0]**2*(1-x[0])**2*sin(4*DOLFIN_PI*x[1])
        values[0] = x[0]*(1-x[0])*(1-2*x[0])*sin(4*DOLFIN_PI*x[1])
        values[1] = 2*DOLFIN_PI*x[0]**2*(1-x[0])**2*cos(4*DOLFIN_PI*x[1])
    def value_shape(self):
        return (2,)

# %%
class DirichletBoundary(SubDomain):
    def inside(self, x, on_boundary):
        return abs(x[0]) < DOLFIN_EPS and on_boundary

# %% [markdown]
# # Discrete spaces
#
# In-plane displacements (IPD) are discretized with $(P_2)^2$. Out-of-plane displacements with a mixed function space $P_2 \ast (P_1)^2$.

# %%
msh = RectangleMesh(Point(0.0, -0.5), Point(1.0, 0.5), 20, 20)

U = VectorFunctionSpace(msh, "Lagrange", 1, dim=2)        # in plane displacements (IPD)
V = VectorFunctionSpace(msh, "Lagrange", 1, dim=2)        # Gradients of out of plane displacements (OPD)

u  = Function(U)
v  = Function(V)
u_ = Function(U)    # solution from previous step
v_ = Function(V)    # solution from previous step

u_init = InitialInPlaneDisplacements(degree=1)
u_.interpolate(u_init)

v_init = InitialOutOfPlaneDisplacements(degree=1)
v_.interpolate(v_init)

bcU = DirichletBC(U, Expression(("0.0", "-x[1]/10"), element=U.ufl_element()), DirichletBoundary())
bcV = DirichletBC(V, Constant((0.0, 0.0)), DirichletBoundary())

# %%
pl.figure(figsize=(7,7))
_ = plot(v_, title="Initial OPD")

# %% [markdown]
# # Coordinate descent

# %%
def eps(u):
    return (grad(u) + grad(u).T)/2.0

e_stop = msh.hmin()*1e-3

#set_log_level(PROGRESS)
file = File("displacements.pvd")

mu = Constant(1e4)

Id = Identity(2)

phi = TestFunction(U)
psi = TestFunction(V)
dtu = TrialFunction(U)
dtv = TrialFunction(V)

Lu = inner(dtu, phi)*dx
Lv = inner(dtv, psi)*dx

# %%
zero_energy = assemble((1./24)*inner(Id, Id)*dx(msh))
def energy(u, v, mu=mu):
    J = (1./2)*inner(eps(u)+outer(v, v)/2, eps(u)+outer(v, v)/2)*dx \
        + (1./24)*inner(grad(v) - Id, grad(v) - Id)*dx \
        + mu*inner(v, v)*dx
    return assemble(J)

# %%
du = Function(U)
dv = Function(V)
step = 0
tau = 1.0
omega = 0.25

cur_energy = energy(u, v)

while step < 10:
    print("Step %d, energy = %e" % (step, cur_energy))
    #This of course won't work
    dJu = inner(eps(u_)+outer(v_, v_)/2, eps(phi))*dx
    dJv = inner(eps(u_)+outer(v_, v_)/2, outer(v_, psi))*dx \
          + (1./12)*inner(grad(v_)-Id, grad(psi))*dx \
          + 2*mu*inner(v_, psi)*dx

    solve(Lu == -dJu, du, bcU)
    solve(Lv == -dJv, dv, bcV)
    
    ndu = norm(du.vector())
    ndv = norm(dv.vector())
    
    print("|du| = %.3f" % ndu)
    print("|dv| = %.3f" % ndv)

    ## line search
    new_energy = 0
    alpha = tau
    while True:
        u = project(u_ + alpha*du, U)
        v = project(v_ + alpha*dv, V)
        new_energy = energy(u, v)
        print("New energy: %e, alpha = %.2e" % (new_energy, alpha))
        if new_energy <= cur_energy - omega*alpha*(ndu**2+ndv**2):
            print("Line search ended with alpha = %e" % alpha)
            cur_energy = new_energy
            break
        if alpha < (1./2)**30:
            raise Exception("Line search failed after 30 steps")
        alpha *= 0.5
    
    file << (u, tau)
    file << (v, tau)
    
    u_.vector()[:] = u.vector()
    v_.vector()[:] = v.vector()
    
    step += 1

# %% [markdown]
# # Gradient descent

# %%
class InitialDisplacements(Expression):     
    def eval(self, values, x):
        values[0] = 0.0
        values[1] = -x[1]/10.0
        values[2] = x[0]*(1-x[0])*(1-2*x[0])*sin(4*DOLFIN_PI*x[1])
        values[3] = 2*DOLFIN_PI*x[0]**2*(1-x[0])**2*cos(4*DOLFIN_PI*x[1])
    def value_shape(self):
        return (4,)

msh = RectangleMesh(Point(0.0, -0.5), Point(1.0, 0.5), 20, 20)

UE = VectorElement("Lagrange", msh.ufl_cell(), 1, dim=2)        # in plane displacements (IPD)
VE = VectorElement("Lagrange", msh.ufl_cell(), 1, dim=2)        # Gradients of out of plane displacements (OPD)
W = FunctionSpace(msh, UE*VE)

bcU = DirichletBC(W.sub(0), Expression(("0.0", "-x[1]/10"), element=UE), DirichletBoundary())
bcV = DirichletBC(W.sub(1), Constant((0.0, 0.0)), DirichletBoundary())

w = Function(W)
w_ = Function(W)
u, v  = w.split()
u_, v_ = w_.split()

w_init = InitialDisplacements(degree=1)
w.interpolate(w_init)
w_.interpolate(w_init)


def eps(u):
    return (grad(u) + grad(u).T)/2.0

e_stop = msh.hmin()*1e-4

file = File("steepest-descent.pvd")

mu = Constant(1e4)

Id = Identity(2)

z = TestFunction(W)
dtz = TrialFunction(W)
L = inner(dtz, z)*dx

zero_energy = assemble((1./24)*inner(Id, Id)*dx(msh))
def energy(u, v, mu=mu):
    J = (1./2)*inner(eps(u)+outer(v, v)/2, eps(u)+outer(v, v)/2)*dx \
        + (1./24)*inner(grad(v) - Id, grad(v) - Id)*dx \
        + mu*inner(v, v)*dx
    return assemble(J)

phi,psi = TestFunctions(W)

dw = Function(W)
du, dv = dw.split()
step = 0
tau = 2**-5
omega = 0.25

cur_energy = energy(u, v)

alpha = ndu = ndv = 1.0
history = {'J':[], 'alpha':[]}

while alpha*(ndu**2+ndv**2) > e_stop and step < 1000:
    print("Step %d, energy = %.3e, curl = %.3e" % (step, cur_energy, assemble(curl(w.sub(1))*dx)))
    dJ = inner(eps(u_)+outer(v_, v_)/2, eps(phi))*dx \
        + inner(eps(u_)+outer(v_, v_)/2, outer(v_, psi))*dx \
        + (1./12)*inner(grad(v_)-Id, grad(psi))*dx \
        + 2*mu*inner(v_, psi)*dx

    print("\tSolving...", end='')
    solve(L == -dJ, dw, [bcU, bcV])
    
    # dw is not assigned to a new object so it's ok to reuse du, dv without splitting
    ndu = norm(du)
    ndv = norm(dv)
    
    print(" done with |du| = %.3f, |dv| = %.3f" % (ndu, ndv), end='')

    # line search
    new_energy = 0
    alpha = tau
    while True:
        w = project(w_ + alpha*dw, W)
        u, v = split(w)
        new_energy = energy(u, v)
        #print("New energy: %e, alpha = %.2e" % (new_energy, alpha))
        if new_energy <= cur_energy - omega*alpha*(ndu**2+ndv**2):
            print(", alpha = %.3e" % alpha)
            history['J'].append(cur_energy)
            history['alpha'].append(alpha)
            cur_energy = new_energy
            break
        if alpha < (1./2)**30:
            raise Exception("Line search failed after 30 steps")
        alpha *= 0.5
    w.rename("disp", "displacement")
    file << (w.split()[0], float(step))
    file << (w.split()[1], float(step))
    
    w_.vector()[:] = w.vector()
    u_, v_ = w_.split()

    step += 1
# Out:
# Step 0, energy = 3.142e+02, curl = -4.283e-18
# 	Solving... done with |du| = 0.951, |dv| = 3546.015, alpha = 6.104e-05
# Step 1, energy = 1.552e+01, curl = 6.017e-06
# 	Solving... done with |du| = 1.039, |dv| = 785.836, alpha = 6.104e-05
# Step 2, energy = 8.458e-01, curl = -2.952e-06
# 	Solving... done with |du| = 0.925, |dv| = 174.149, alpha = 6.104e-05
# Step 3, energy = 1.253e-01, curl = 1.087e-06
# 	Solving... done with |du| = 0.830, |dv| = 38.594, alpha = 6.104e-05
# Step 4, energy = 8.992e-02, curl = -3.556e-07
# 	Solving... done with |du| = 0.760, |dv| = 8.553, alpha = 6.104e-05
# Step 5, energy = 8.815e-02, curl = 1.092e-07
# 	Solving... done with |du| = 0.708, |dv| = 1.895, alpha = 6.104e-05
# Step 6, energy = 8.803e-02, curl = -3.221e-08
# 	Solving... done with |du| = 0.668, |dv| = 0.420, alpha = 1.221e-04
# Step 7, energy = 8.798e-02, curl = 5.075e-08
# 	Solving... done with |du| = 0.608, |dv| = 0.606, alpha = 1.221e-04
# Step 8, energy = 8.795e-02, curl = -7.967e-08
# 	Solving... done with |du| = 0.569, |dv| = 0.875, alpha = 6.104e-05
# Step 9, energy = 8.791e-02, curl = 2.261e-08
# 	Solving... done with |du| = 0.554, |dv| = 0.194, alpha = 4.883e-04
# Step 10, energy = 8.785e-02, curl = -2.087e-07
# 	Solving... done with |du| = 0.469, |dv| = 1.701, alpha = 6.104e-05
# Step 11, energy = 8.777e-02, curl = 5.813e-08
# 	Solving... done with |du| = 0.463, |dv| = 0.377, alpha = 1.221e-04
# Step 12, energy = 8.774e-02, curl = -9.014e-08
# 	Solving... done with |du| = 0.452, |dv| = 0.544, alpha = 1.221e-04
# Step 13, energy = 8.773e-02, curl = 1.397e-07
# 	Solving... done with |du| = 0.443, |dv| = 0.785, alpha = 6.104e-05
# Step 14, energy = 8.770e-02, curl = -3.828e-08
# 	Solving... done with |du| = 0.438, |dv| = 0.174, alpha = 4.883e-04
# Step 15, energy = 8.767e-02, curl = 3.515e-07
# 	Solving... done with |du| = 0.407, |dv| = 1.527, alpha = 6.104e-05
# Step 16, energy = 8.760e-02, curl = -9.559e-08
# 	Solving... done with |du| = 0.404, |dv| = 0.338, alpha = 1.221e-04
# Step 17, energy = 8.759e-02, curl = 1.474e-07
# 	Solving... done with |du| = 0.398, |dv| = 0.488, alpha = 1.221e-04
# Step 18, energy = 8.757e-02, curl = -2.271e-07
# 	Solving... done with |du| = 0.393, |dv| = 0.705, alpha = 6.104e-05
# Step 19, energy = 8.755e-02, curl = 6.139e-08
# 	Solving... done with |du| = 0.391, |dv| = 0.156, alpha = 4.883e-04
# Step 20, energy = 8.753e-02, curl = -5.620e-07
# 	Solving... done with |du| = 0.372, |dv| = 1.371, alpha = 6.104e-05
# Step 21, energy = 8.747e-02, curl = 1.515e-07
# 	Solving... done with |du| = 0.370, |dv| = 0.304, alpha = 1.221e-04
# Step 22, energy = 8.746e-02, curl = -2.329e-07
# 	Solving... done with |du| = 0.366, |dv| = 0.439, alpha = 1.221e-04
# Step 23, energy = 8.745e-02, curl = 3.583e-07
# 	Solving... done with |du| = 0.362, |dv| = 0.633, alpha = 6.104e-05
# Step 24, energy = 8.743e-02, curl = -9.634e-08
# 	Solving... done with |du| = 0.361, |dv| = 0.140, alpha = 4.883e-04
# Step 25, energy = 8.741e-02, curl = 8.817e-07
# 	Solving... done with |du| = 0.347, |dv| = 1.231, alpha = 6.104e-05
# Step 26, energy = 8.736e-02, curl = -2.370e-07
# 	Solving... done with |du| = 0.346, |dv| = 0.273, alpha = 1.221e-04
# Step 27, energy = 8.735e-02, curl = 3.646e-07
# 	Solving... done with |du| = 0.343, |dv| = 0.394, alpha = 1.221e-04
# Step 28, energy = 8.734e-02, curl = -5.606e-07
# 	Solving... done with |du| = 0.340, |dv| = 0.569, alpha = 6.104e-05
# Step 29, energy = 8.733e-02, curl = 1.508e-07
# 	Solving... done with |du| = 0.339, |dv| = 0.126, alpha = 4.883e-04
# Step 30, energy = 8.730e-02, curl = -1.381e-06
# 	Solving... done with |du| = 0.329, |dv| = 1.107, alpha = 6.104e-05
# Step 31, energy = 8.727e-02, curl = 3.718e-07
# 	Solving... done with |du| = 0.328, |dv| = 0.245, alpha = 1.221e-04
# Step 32, energy = 8.725e-02, curl = -5.723e-07
# 	Solving... done with |du| = 0.326, |dv| = 0.354, alpha = 1.221e-04
# Step 33, energy = 8.724e-02, curl = 8.811e-07
# 	Solving... done with |du| = 0.324, |dv| = 0.512, alpha = 6.104e-05
# Step 34, energy = 8.723e-02, curl = -2.377e-07
# 	Solving... done with |du| = 0.323, |dv| = 0.114, alpha = 4.883e-04
# Step 35, energy = 8.721e-02, curl = 2.178e-06
# 	Solving... done with |du| = 0.314, |dv| = 0.997, alpha = 6.104e-05
# Step 36, energy = 8.718e-02, curl = -5.888e-07
# 	Solving... done with |du| = 0.314, |dv| = 0.221, alpha = 1.221e-04
# Step 37, energy = 8.717e-02, curl = 9.076e-07
# 	Solving... done with |du| = 0.312, |dv| = 0.320, alpha = 1.221e-04
# Step 38, energy = 8.716e-02, curl = -1.399e-06
# 	Solving... done with |du| = 0.310, |dv| = 0.462, alpha = 6.104e-05
# Step 39, energy = 8.715e-02, curl = 3.792e-07
# 	Solving... done with |du| = 0.309, |dv| = 0.103, alpha = 4.883e-04
# Step 40, energy = 8.712e-02, curl = -3.477e-06
# 	Solving... done with |du| = 0.302, |dv| = 0.902, alpha = 6.104e-05
# Step 41, energy = 8.710e-02, curl = 9.442e-07
# 	Solving... done with |du| = 0.302, |dv| = 0.201, alpha = 1.221e-04
# Step 42, energy = 8.709e-02, curl = -1.458e-06
# 	Solving... done with |du| = 0.300, |dv| = 0.291, alpha = 1.221e-04
# Step 43, energy = 8.708e-02, curl = 2.251e-06
# 	Solving... done with |du| = 0.299, |dv| = 0.421, alpha = 6.104e-05
# Step 44, energy = 8.707e-02, curl = -6.127e-07
# 	Solving... done with |du| = 0.298, |dv| = 0.094, alpha = 4.883e-04
# Step 45, energy = 8.704e-02, curl = 5.625e-06
# 	Solving... done with |du| = 0.292, |dv| = 0.830, alpha = 6.104e-05
# Step 46, energy = 8.702e-02, curl = -1.534e-06
# 	Solving... done with |du| = 0.292, |dv| = 0.187, alpha = 2.441e-04
# Step 47, energy = 8.701e-02, curl = 6.278e-06
# 	Solving... done with |du| = 0.289, |dv| = 0.731, alpha = 6.104e-05
# Step 48, energy = 8.700e-02, curl = -1.715e-06
# 	Solving... done with |du| = 0.288, |dv| = 0.166, alpha = 2.441e-04
# Step 49, energy = 8.699e-02, curl = 7.023e-06
# 	Solving... done with |du| = 0.286, |dv| = 0.653, alpha = 6.104e-05
# Step 50, energy = 8.697e-02, curl = -1.922e-06
# 	Solving... done with |du| = 0.285, |dv| = 0.151, alpha = 2.441e-04
# Step 51, energy = 8.696e-02, curl = 7.872e-06
# 	Solving... done with |du| = 0.283, |dv| = 0.594, alpha = 6.104e-05
# Step 52, energy = 8.695e-02, curl = -2.158e-06
# 	Solving... done with |du| = 0.282, |dv| = 0.140, alpha = 2.441e-04
# Step 53, energy = 8.693e-02, curl = 8.842e-06
# 	Solving... done with |du| = 0.280, |dv| = 0.555, alpha = 6.104e-05
# Step 54, energy = 8.692e-02, curl = -2.427e-06
# 	Solving... done with |du| = 0.279, |dv| = 0.135, alpha = 2.441e-04
# Step 55, energy = 8.691e-02, curl = 9.949e-06
# 	Solving... done with |du| = 0.277, |dv| = 0.537, alpha = 6.104e-05
# Step 56, energy = 8.690e-02, curl = -2.735e-06
# 	Solving... done with |du| = 0.277, |dv| = 0.134, alpha = 2.441e-04
# Step 57, energy = 8.689e-02, curl = 1.121e-05
# 	Solving... done with |du| = 0.275, |dv| = 0.538, alpha = 6.104e-05
# Step 58, energy = 8.688e-02, curl = -3.086e-06
# 	Solving... done with |du| = 0.274, |dv| = 0.138, alpha = 2.441e-04
# Step 59, energy = 8.686e-02, curl = 1.266e-05
# 	Solving... done with |du| = 0.272, |dv| = 0.559, alpha = 6.104e-05
# Step 60, energy = 8.685e-02, curl = -3.487e-06
# 	Solving... done with |du| = 0.272, |dv| = 0.147, alpha = 2.441e-04
# Step 61, energy = 8.684e-02, curl = 1.431e-05
# 	Solving... done with |du| = 0.270, |dv| = 0.599, alpha = 6.104e-05
# Step 62, energy = 8.683e-02, curl = -3.945e-06
# 	Solving... done with |du| = 0.269, |dv| = 0.161, alpha = 2.441e-04
# Step 63, energy = 8.682e-02, curl = 1.619e-05
# 	Solving... done with |du| = 0.267, |dv| = 0.656, alpha = 6.104e-05
# Step 64, energy = 8.681e-02, curl = -4.469e-06
# 	Solving... done with |du| = 0.267, |dv| = 0.178, alpha = 1.221e-04
# Step 65, energy = 8.680e-02, curl = 6.937e-06
# 	Solving... done with |du| = 0.266, |dv| = 0.275, alpha = 1.221e-04
# Step 66, energy = 8.680e-02, curl = -1.077e-05
# 	Solving... done with |du| = 0.265, |dv| = 0.426, alpha = 6.104e-05
# Step 67, energy = 8.679e-02, curl = 2.976e-06
# 	Solving... done with |du| = 0.265, |dv| = 0.117, alpha = 2.441e-04
# Step 68, energy = 8.678e-02, curl = -1.222e-05
# 	Solving... done with |du| = 0.263, |dv| = 0.480, alpha = 6.104e-05
# Step 69, energy = 8.677e-02, curl = 3.378e-06
# 	Solving... done with |du| = 0.263, |dv| = 0.132, alpha = 2.441e-04
# Step 70, energy = 8.676e-02, curl = -1.387e-05
# 	Solving... done with |du| = 0.261, |dv| = 0.543, alpha = 6.104e-05
# Step 71, energy = 8.675e-02, curl = 3.837e-06
# 	Solving... done with |du| = 0.261, |dv| = 0.150, alpha = 2.441e-04
# Step 72, energy = 8.674e-02, curl = -1.576e-05
# 	Solving... done with |du| = 0.259, |dv| = 0.616, alpha = 6.104e-05
# Step 73, energy = 8.673e-02, curl = 4.362e-06
# 	Solving... done with |du| = 0.259, |dv| = 0.171, alpha = 1.221e-04
# Step 74, energy = 8.672e-02, curl = -6.778e-06
# 	Solving... done with |du| = 0.258, |dv| = 0.265, alpha = 1.221e-04
# Step 75, energy = 8.671e-02, curl = 1.053e-05
# 	Solving... done with |du| = 0.257, |dv| = 0.412, alpha = 6.104e-05
# Step 76, energy = 8.671e-02, curl = -2.917e-06
# 	Solving... done with |du| = 0.257, |dv| = 0.114, alpha = 2.441e-04
# Step 77, energy = 8.669e-02, curl = 1.198e-05
# 	Solving... done with |du| = 0.255, |dv| = 0.470, alpha = 6.104e-05
# Step 78, energy = 8.669e-02, curl = -3.320e-06
# 	Solving... done with |du| = 0.255, |dv| = 0.130, alpha = 2.441e-04
# Step 79, energy = 8.668e-02, curl = 1.364e-05
# 	Solving... done with |du| = 0.253, |dv| = 0.535, alpha = 6.104e-05
# Step 80, energy = 8.667e-02, curl = -3.780e-06
# 	Solving... done with |du| = 0.253, |dv| = 0.149, alpha = 2.441e-04
# Step 81, energy = 8.666e-02, curl = 1.553e-05
# 	Solving... done with |du| = 0.252, |dv| = 0.611, alpha = 6.104e-05
# Step 82, energy = 8.665e-02, curl = -4.306e-06
# 	Solving... done with |du| = 0.251, |dv| = 0.170, alpha = 1.221e-04
# Step 83, energy = 8.664e-02, curl = 6.694e-06
# 	Solving... done with |du| = 0.250, |dv| = 0.264, alpha = 1.221e-04
# Step 84, energy = 8.664e-02, curl = -1.041e-05
# 	Solving... done with |du| = 0.250, |dv| = 0.410, alpha = 6.104e-05
# Step 85, energy = 8.663e-02, curl = 2.886e-06
# 	Solving... done with |du| = 0.249, |dv| = 0.114, alpha = 2.441e-04
# Step 86, energy = 8.662e-02, curl = -1.186e-05
# 	Solving... done with |du| = 0.248, |dv| = 0.468, alpha = 6.104e-05
# Step 87, energy = 8.661e-02, curl = 3.290e-06
# 	Solving... done with |du| = 0.248, |dv| = 0.130, alpha = 2.441e-04
# Step 88, energy = 8.660e-02, curl = -1.352e-05
# 	Solving... done with |du| = 0.247, |dv| = 0.534, alpha = 6.104e-05
# Step 89, energy = 8.659e-02, curl = 3.751e-06
# 	Solving... done with |du| = 0.246, |dv| = 0.148, alpha = 2.441e-04
# Step 90, energy = 8.658e-02, curl = -1.542e-05
# 	Solving... done with |du| = 0.245, |dv| = 0.610, alpha = 6.104e-05
# Step 91, energy = 8.657e-02, curl = 4.277e-06
# 	Solving... done with |du| = 0.245, |dv| = 0.169, alpha = 1.221e-04
# Step 92, energy = 8.657e-02, curl = -6.652e-06
# 	Solving... done with |du| = 0.244, |dv| = 0.263, alpha = 1.221e-04
# Step 93, energy = 8.656e-02, curl = 1.034e-05
# 	Solving... done with |du| = 0.243, |dv| = 0.410, alpha = 6.104e-05
# Step 94, energy = 8.655e-02, curl = -2.871e-06
# 	Solving... done with |du| = 0.243, |dv| = 0.114, alpha = 2.441e-04
# Step 95, energy = 8.655e-02, curl = 1.180e-05
# 	Solving... done with |du| = 0.242, |dv| = 0.468, alpha = 6.104e-05
# Step 96, energy = 8.654e-02, curl = -3.275e-06
# 	Solving... done with |du| = 0.242, |dv| = 0.130, alpha = 2.441e-04
# Step 97, energy = 8.653e-02, curl = 1.346e-05
# 	Solving... done with |du| = 0.240, |dv| = 0.534, alpha = 6.104e-05
# Step 98, energy = 8.652e-02, curl = -3.737e-06
# 	Solving... done with |du| = 0.240, |dv| = 0.148, alpha = 2.441e-04
# Step 99, energy = 8.651e-02, curl = 1.536e-05
# 	Solving... done with |du| = 0.239, |dv| = 0.610, alpha = 6.104e-05
# Step 100, energy = 8.650e-02, curl = -4.265e-06
# 	Solving... done with |du| = 0.239, |dv| = 0.169, alpha = 1.221e-04
# Step 101, energy = 8.650e-02, curl = 6.633e-06
# 	Solving... done with |du| = 0.238, |dv| = 0.264, alpha = 1.221e-04
# Step 102, energy = 8.649e-02, curl = -1.032e-05
# 	Solving... done with |du| = 0.238, |dv| = 0.410, alpha = 6.104e-05
# Step 103, energy = 8.649e-02, curl = 2.864e-06
# 	Solving... done with |du| = 0.237, |dv| = 0.114, alpha = 2.441e-04
# Step 104, energy = 8.648e-02, curl = -1.177e-05
# 	Solving... done with |du| = 0.236, |dv| = 0.468, alpha = 6.104e-05
# Step 105, energy = 8.647e-02, curl = 3.270e-06
# 	Solving... done with |du| = 0.236, |dv| = 0.130, alpha = 2.441e-04
# Step 106, energy = 8.646e-02, curl = -1.344e-05
# 	Solving... done with |du| = 0.235, |dv| = 0.535, alpha = 6.104e-05
# Step 107, energy = 8.645e-02, curl = 3.732e-06
# 	Solving... done with |du| = 0.235, |dv| = 0.149, alpha = 2.441e-04
# Step 108, energy = 8.645e-02, curl = -1.534e-05
# 	Solving... done with |du| = 0.234, |dv| = 0.611, alpha = 6.104e-05
# Step 109, energy = 8.644e-02, curl = 4.261e-06
# 	Solving... done with |du| = 0.233, |dv| = 0.170, alpha = 1.221e-04
# Step 110, energy = 8.643e-02, curl = -6.627e-06
# 	Solving... done with |du| = 0.233, |dv| = 0.264, alpha = 1.221e-04
# Step 111, energy = 8.643e-02, curl = 1.031e-05
# 	Solving... done with |du| = 0.232, |dv| = 0.411, alpha = 6.104e-05
# Step 112, energy = 8.642e-02, curl = -2.863e-06
# 	Solving... done with |du| = 0.232, |dv| = 0.114, alpha = 2.441e-04
# Step 113, energy = 8.641e-02, curl = 1.177e-05
# 	Solving... done with |du| = 0.231, |dv| = 0.469, alpha = 6.104e-05
# Step 114, energy = 8.640e-02, curl = -3.269e-06
# 	Solving... done with |du| = 0.231, |dv| = 0.130, alpha = 2.441e-04
# Step 115, energy = 8.640e-02, curl = 1.344e-05
# 	Solving... done with |du| = 0.230, |dv| = 0.536, alpha = 6.104e-05
# Step 116, energy = 8.639e-02, curl = -3.732e-06
# 	Solving... done with |du| = 0.230, |dv| = 0.149, alpha = 1.221e-04
# Step 117, energy = 8.638e-02, curl = 5.806e-06
# 	Solving... done with |du| = 0.229, |dv| = 0.231, alpha = 1.221e-04
# Step 118, energy = 8.638e-02, curl = -9.031e-06
# 	Solving... done with |du| = 0.229, |dv| = 0.360, alpha = 6.104e-05
# Step 119, energy = 8.637e-02, curl = 2.508e-06
# 	Solving... done with |du| = 0.229, |dv| = 0.100, alpha = 2.441e-04
# Step 120, energy = 8.636e-02, curl = -1.031e-05
# 	Solving... done with |du| = 0.228, |dv| = 0.411, alpha = 6.104e-05
# Step 121, energy = 8.636e-02, curl = 2.864e-06
# 	Solving... done with |du| = 0.227, |dv| = 0.114, alpha = 2.441e-04
# Step 122, energy = 8.635e-02, curl = -1.178e-05
# 	Solving... done with |du| = 0.226, |dv| = 0.470, alpha = 6.104e-05
# Step 123, energy = 8.634e-02, curl = 3.271e-06
# 	Solving... done with |du| = 0.226, |dv| = 0.131, alpha = 2.441e-04
# Step 124, energy = 8.633e-02, curl = -1.345e-05
# 	Solving... done with |du| = 0.225, |dv| = 0.537, alpha = 6.104e-05
# Step 125, energy = 8.633e-02, curl = 3.735e-06
# 	Solving... done with |du| = 0.225, |dv| = 0.149, alpha = 1.221e-04
# Step 126, energy = 8.632e-02, curl = -5.810e-06
# 	Solving... done with |du| = 0.225, |dv| = 0.232, alpha = 1.221e-04
# Step 127, energy = 8.632e-02, curl = 9.038e-06
# 	Solving... done with |du| = 0.224, |dv| = 0.361, alpha = 6.104e-05
# Step 128, energy = 8.631e-02, curl = -2.511e-06
# 	Solving... done with |du| = 0.224, |dv| = 0.100, alpha = 2.441e-04
# Step 129, energy = 8.630e-02, curl = 1.032e-05
# 	Solving... done with |du| = 0.223, |dv| = 0.412, alpha = 6.104e-05
# Step 130, energy = 8.629e-02, curl = -2.867e-06
# 	Solving... done with |du| = 0.223, |dv| = 0.114, alpha = 2.441e-04
# Step 131, energy = 8.629e-02, curl = 1.179e-05
# 	Solving... done with |du| = 0.222, |dv| = 0.471, alpha = 6.104e-05
# Step 132, energy = 8.628e-02, curl = -3.275e-06
# 	Solving... done with |du| = 0.222, |dv| = 0.131, alpha = 2.441e-04
# Step 133, energy = 8.627e-02, curl = 1.346e-05
# 	Solving... done with |du| = 0.221, |dv| = 0.538, alpha = 6.104e-05
# Step 134, energy = 8.627e-02, curl = -3.740e-06
# 	Solving... done with |du| = 0.221, |dv| = 0.149, alpha = 1.221e-04
# Step 135, energy = 8.626e-02, curl = 5.818e-06
# 	Solving... done with |du| = 0.220, |dv| = 0.232, alpha = 1.221e-04
# Step 136, energy = 8.626e-02, curl = -9.050e-06
# 	Solving... done with |du| = 0.220, |dv| = 0.361, alpha = 6.104e-05
# Step 137, energy = 8.625e-02, curl = 2.514e-06
# 	Solving... done with |du| = 0.220, |dv| = 0.100, alpha = 2.441e-04
# Step 138, energy = 8.624e-02, curl = -1.034e-05
# 	Solving... done with |du| = 0.219, |dv| = 0.413, alpha = 6.104e-05
# Step 139, energy = 8.624e-02, curl = 2.871e-06
# 	Solving... done with |du| = 0.219, |dv| = 0.115, alpha = 2.441e-04
# Step 140, energy = 8.623e-02, curl = -1.180e-05
# 	Solving... done with |du| = 0.218, |dv| = 0.472, alpha = 6.104e-05
# Step 141, energy = 8.622e-02, curl = 3.279e-06
# 	Solving... done with |du| = 0.218, |dv| = 0.131, alpha = 2.441e-04
# Step 142, energy = 8.622e-02, curl = -1.348e-05
# 	Solving... done with |du| = 0.217, |dv| = 0.539, alpha = 6.104e-05
# Step 143, energy = 8.621e-02, curl = 3.746e-06
# 	Solving... done with |du| = 0.217, |dv| = 0.150, alpha = 1.221e-04
# Step 144, energy = 8.620e-02, curl = -5.827e-06
# 	Solving... done with |du| = 0.216, |dv| = 0.233, alpha = 1.221e-04
# Step 145, energy = 8.620e-02, curl = 9.064e-06
# 	Solving... done with |du| = 0.216, |dv| = 0.362, alpha = 6.104e-05
# Step 146, energy = 8.619e-02, curl = -2.518e-06
# 	Solving... done with |du| = 0.216, |dv| = 0.101, alpha = 2.441e-04
# Step 147, energy = 8.619e-02, curl = 1.035e-05
# 	Solving... done with |du| = 0.215, |dv| = 0.414, alpha = 6.104e-05
# Step 148, energy = 8.618e-02, curl = -2.876e-06
# 	Solving... done with |du| = 0.215, |dv| = 0.115, alpha = 2.441e-04
# Step 149, energy = 8.617e-02, curl = 1.182e-05
# 	Solving... done with |du| = 0.214, |dv| = 0.473, alpha = 6.104e-05
# Step 150, energy = 8.617e-02, curl = -3.285e-06
# 	Solving... done with |du| = 0.214, |dv| = 0.131, alpha = 2.441e-04
# Step 151, energy = 8.616e-02, curl = 1.351e-05
# 	Solving... done with |du| = 0.213, |dv| = 0.540, alpha = 6.104e-05
# Step 152, energy = 8.615e-02, curl = -3.752e-06
# 	Solving... done with |du| = 0.213, |dv| = 0.150, alpha = 1.221e-04
# Step 153, energy = 8.615e-02, curl = 5.837e-06
# 	Solving... done with |du| = 0.213, |dv| = 0.233, alpha = 1.221e-04
# Step 154, energy = 8.615e-02, curl = -9.080e-06
# 	Solving... done with |du| = 0.212, |dv| = 0.363, alpha = 6.104e-05
# Step 155, energy = 8.614e-02, curl = 2.523e-06
# 	Solving... done with |du| = 0.212, |dv| = 0.101, alpha = 2.441e-04
# Step 156, energy = 8.613e-02, curl = -1.037e-05
# 	Solving... done with |du| = 0.211, |dv| = 0.415, alpha = 6.104e-05
# Step 157, energy = 8.613e-02, curl = 2.881e-06
# 	Solving... done with |du| = 0.211, |dv| = 0.115, alpha = 2.441e-04
# Step 158, energy = 8.612e-02, curl = -1.185e-05
# 	Solving... done with |du| = 0.210, |dv| = 0.474, alpha = 6.104e-05
# Step 159, energy = 8.611e-02, curl = 3.291e-06
# 	Solving... done with |du| = 0.210, |dv| = 0.132, alpha = 2.441e-04
# Step 160, energy = 8.611e-02, curl = -1.353e-05
# 	Solving... done with |du| = 0.210, |dv| = 0.541, alpha = 6.104e-05
# Step 161, energy = 8.610e-02, curl = 3.759e-06
# 	Solving... done with |du| = 0.209, |dv| = 0.150, alpha = 1.221e-04
# Step 162, energy = 8.610e-02, curl = -5.848e-06
# 	Solving... done with |du| = 0.209, |dv| = 0.234, alpha = 1.221e-04
# Step 163, energy = 8.609e-02, curl = 9.097e-06
# 	Solving... done with |du| = 0.209, |dv| = 0.364, alpha = 6.104e-05
# Step 164, energy = 8.609e-02, curl = -2.527e-06
# 	Solving... done with |du| = 0.209, |dv| = 0.101, alpha = 2.441e-04
# Step 165, energy = 8.608e-02, curl = 1.039e-05
# 	Solving... done with |du| = 0.208, |dv| = 0.416, alpha = 6.104e-05
# Step 166, energy = 8.607e-02, curl = -2.887e-06
# 	Solving... done with |du| = 0.208, |dv| = 0.115, alpha = 2.441e-04
# Step 167, energy = 8.607e-02, curl = 1.187e-05
# 	Solving... done with |du| = 0.207, |dv| = 0.475, alpha = 6.104e-05
# Step 168, energy = 8.606e-02, curl = -3.297e-06
# 	Solving... done with |du| = 0.207, |dv| = 0.132, alpha = 1.221e-04
# Step 169, energy = 8.606e-02, curl = 5.130e-06
# 	Solving... done with |du| = 0.206, |dv| = 0.205, alpha = 1.221e-04
# Step 170, energy = 8.605e-02, curl = -7.980e-06
# 	Solving... done with |du| = 0.206, |dv| = 0.319, alpha = 6.104e-05
# Step 171, energy = 8.605e-02, curl = 2.217e-06
# 	Solving... done with |du| = 0.206, |dv| = 0.089, alpha = 2.441e-04
# Step 172, energy = 8.604e-02, curl = -9.115e-06
# 	Solving... done with |du| = 0.205, |dv| = 0.365, alpha = 6.104e-05
# Step 173, energy = 8.604e-02, curl = 2.532e-06
# 	Solving... done with |du| = 0.205, |dv| = 0.101, alpha = 2.441e-04
# Step 174, energy = 8.603e-02, curl = -1.041e-05
# 	Solving... done with |du| = 0.204, |dv| = 0.417, alpha = 6.104e-05
# Step 175, energy = 8.602e-02, curl = 2.893e-06
# 	Solving... done with |du| = 0.204, |dv| = 0.116, alpha = 2.441e-04
# Step 176, energy = 8.602e-02, curl = -1.189e-05
# 	Solving... done with |du| = 0.204, |dv| = 0.476, alpha = 6.104e-05
# Step 177, energy = 8.601e-02, curl = 3.304e-06
# 	Solving... done with |du| = 0.204, |dv| = 0.132, alpha = 1.221e-04
# Step 178, energy = 8.601e-02, curl = -5.140e-06
# 	Solving... done with |du| = 0.203, |dv| = 0.206, alpha = 1.221e-04
# Step 179, energy = 8.600e-02, curl = 7.996e-06
# 	Solving... done with |du| = 0.203, |dv| = 0.320, alpha = 6.104e-05
# Step 180, energy = 8.600e-02, curl = -2.222e-06
# 	Solving... done with |du| = 0.203, |dv| = 0.089, alpha = 2.441e-04
# Step 181, energy = 8.599e-02, curl = 9.134e-06
# 	Solving... done with |du| = 0.202, |dv| = 0.366, alpha = 6.104e-05
# Step 182, energy = 8.599e-02, curl = -2.538e-06
# 	Solving... done with |du| = 0.202, |dv| = 0.102, alpha = 2.441e-04
# Step 183, energy = 8.598e-02, curl = 1.043e-05
# 	Solving... done with |du| = 0.201, |dv| = 0.418, alpha = 6.104e-05
# Step 184, energy = 8.597e-02, curl = -2.899e-06
# 	Solving... done with |du| = 0.201, |dv| = 0.116, alpha = 2.441e-04
# Step 185, energy = 8.597e-02, curl = 1.192e-05
# 	Solving... done with |du| = 0.200, |dv| = 0.477, alpha = 6.104e-05
# Step 186, energy = 8.596e-02, curl = -3.311e-06
# 	Solving... done with |du| = 0.200, |dv| = 0.133, alpha = 1.221e-04

# %%
pl.plot(np.log(history['J'][5:]))
_ = pl.title('$log\ J$')

# %%
w.interpolate(w_init)

P = FunctionSpace(msh, "Lagrange", 1)
bcP = DirichletBC(P, Constant(0.0), DirichletBoundary())

p = TrialFunction(P)
q = TestFunction(P)
z = TestFunction(P)

a = inner(p.dx(0), q)*dx + inner(p.dx(1), z)*dx
L = inner(w.split()[1].sub(0), q)*dx + inner(w.split()[1].sub(1), z)*dx
opd = Function(P)
solve(a == L, opd, bcP)

# %%
plot(opd)

# %%
orig = Function(W)
orig.interpolate(wdw_init)

diff = project(orig - dwk)
print(norm(diff.vector(), 'l2'))
print(norm(diff.vector(), 'linf'))

# %%
pl.figure(figsize=(22,8))
pl.subplot(1,3,1)
_ = plot(orig, title="Init: %e - %e" % (orig.vector().min(), orig.vector().max()))
pl.subplot(1,3,2)
_ = plot(dwk, title="Sol: %e - %e" % (dwk.vector().min(), dwk.vector().max()))
pl.subplot(1,3,3)
_ = plot(diff, title="Diff: %e - %e" % (diff.vector().min(), diff.vector().max()))

# %% [markdown]
# # curl constraint

# %%
class InitialDisplacements(Expression):     
    def eval(self, values, x):
        values[0] = 0.0
        values[1] = -x[1]/10.0
        values[2] = x[0]*(1-x[0])*(1-2*x[0])*sin(4*DOLFIN_PI*x[1])
        values[3] = 2*DOLFIN_PI*x[0]**2*(1-x[0])**2*cos(4*DOLFIN_PI*x[1])
    def value_shape(self):
        return (4,)

msh = RectangleMesh(Point(0.0, -0.5), Point(1.0, 0.5), 20, 20)

UE = VectorElement("Lagrange", msh.ufl_cell(), 1, dim=2)        # in plane displacements (IPD)
VE = VectorElement("Lagrange", msh.ufl_cell(), 1, dim=2)        # Gradients of out of plane displacements (OPD)
W = FunctionSpace(msh, UE*VE)

bcU = DirichletBC(W.sub(0), Expression(("0.0", "-x[1]/10"), element=UE), DirichletBoundary())
bcV = DirichletBC(W.sub(1), Constant((0.0, 0.0)), DirichletBoundary())

w = Function(W)
w_ = Function(W)
u, v  = w.split()
u_, v_ = w_.split()

w_init = InitialDisplacements(degree=1)
w.interpolate(w_init)
w_.interpolate(w_init)


def eps(u):
    return (grad(u) + grad(u).T)/2.0

e_stop = msh.hmin()*1e-4

file = File("steepest-descent-curl.pvd")

mu = Constant(1e4)
Id = Identity(2)


zero_energy = assemble((1./24)*inner(Id, Id)*dx(msh))
def energy(u, v, mu=mu):
    J = (1./2)*inner(eps(u)+outer(v, v)/2, eps(u)+outer(v, v)/2)*dx \
        + (1./24)*inner(grad(v) - Id, grad(v) - Id)*dx \
        + mu*inner(curl(v), curl(v))*dx
    return assemble(J)

z = TestFunction(W)
dtz = TrialFunction(W)
L = inner(dtz, z)*dx

phi,psi = TestFunctions(W)

dw = Function(W)
du, dv = dw.split()
step = 0
tau = 2**-5
omega = 0.25

cur_energy = energy(u, v)

alpha = ndu = ndv = 1.0
history = {'J':[], 'alpha':[]}

while alpha*(ndu**2+ndv**2) > e_stop and step < 100:
    print("Step %d, energy = %.3e, curl = %.3e" % (step, cur_energy, assemble(curl(v_)*dx)))
    dJ = inner(eps(u_)+outer(v_, v_)/2, eps(phi))*dx \
        + inner(eps(u_)+outer(v_, v_)/2, outer(v_, psi))*dx \
        + (1./12)*inner(grad(v_)-Id, grad(psi))*dx \
        + 2*mu*inner(curl(v_), curl(psi))*dx

    print("\tSolving...", end='')
    solve(L == -dJ, dw, [bcU, bcV])
    
    # dw is not assigned to a new object so it's ok to reuse du, dv without splitting
    ndu = norm(du)
    ndv = norm(dv)
    
    print(" done with |du| = %.3f, |dv| = %.3f" % (ndu, ndv), end='')

    # line search
    new_energy = 0
    alpha = tau
    while True:
        w = project(w_ + alpha*dw, W)
        u, v = split(w)
        new_energy = energy(u, v)
        #print("New energy: %e, alpha = %.2e" % (new_energy, alpha))
        if new_energy <= cur_energy - omega*alpha*(ndu**2+ndv**2):
            print(", alpha = %e" % alpha)
            history['J'].append(cur_energy)
            history['alpha'].append(alpha)
            cur_energy = new_energy
            break
        if alpha < (1./2)**30:
            raise Exception("Line search failed after 30 steps")
        alpha *= 0.5
    w.rename("disp", "displacement")
    file << (w.split()[0], float(step))
    file << (w.split()[1], float(step))
    
    w_.vector()[:] = w.vector()
    u_, v_ = w_.split()

    step += 1

# %% [markdown]
# # Mixed out-of-plane displacements

# %%
class InitialDisplacements(Expression):     
    def eval(self, values, x):
        values[0] = 0.0
        values[1] = -x[1]/10.0
        values[2] = 0.5*x[0]**2*(1-x[0])**2*sin(4*DOLFIN_PI*x[1])
        values[3] = x[0]*(1-x[0])*(1-2*x[0])*sin(4*DOLFIN_PI*x[1])
        values[4] = 2*DOLFIN_PI*x[0]**2*(1-x[0])**2*cos(4*DOLFIN_PI*x[1])
    def value_shape(self):
        return (5,)

msh = RectangleMesh(Point(0.0, -0.5), Point(1.0, 0.5), 20, 20)

UE = VectorElement("Lagrange", msh.ufl_cell(), 1, dim=2)        # in plane displacements (IPD)
VE = FiniteElement("Lagrange", msh.ufl_cell(), 1)
VVE = VectorElement("Lagrange", msh.ufl_cell(), 1, dim=2)        # Gradients of out of plane displacements (OPD)
ME = MixedElement([UE, VE, VVE])
W = FunctionSpace(msh, ME)

bc = DirichletBC(W, Expression(("0.0", "-x[1]/10", "0.0", "0.0", "0.0"), element=ME),
                 DirichletBoundary())
w = Function(W)
w_ = Function(W)
u, d, v  = w.split()
u_, d_, v_ = w_.split()

w_init = InitialDisplacements(degree=1)
w.interpolate(w_init)
w_.interpolate(w_init)

def eps(u):
    return (grad(u) + grad(u).T)/2.0

e_stop = msh.hmin()*1e-4

file = File("steepest-descent-grad.pvd")

mu = Constant(1e4)
Id = Identity(2)

zero_energy = assemble((1./24)*inner(Id, Id)*dx(msh))
def energy(u, d, v, mu=mu):
    J = (1./2)*inner(eps(u)+outer(v, v)/2, eps(u)+outer(v, v)/2)*dx \
        + (1./24)*inner(grad(v) - Id, grad(v) - Id)*dx \
        + (1./2)*mu*inner(v, v)*dx \
        + (1./2)*mu*inner(v - grad(d), v - grad(d))*dx
        
    return assemble(J)

phi, eta, psi = TestFunctions(W)

dtz = TrialFunction(W)
z = TestFunction(W)
L = inner(dtz, z)*dx

dw = Function(W)
du, dd, dv = dw.split()
step = 0
max_line_steps = 30
tau = 2**-50
omega = 0.25  # fudge factor

cur_energy = energy(u, d, v)

alpha = ndu = ndd = ndv = 1.0
history = {'J':[], 'alpha':[]}

while alpha*(ndu**2+ndd**2+ndv**2) > e_stop and step < 100:
    print("Step %d, energy = %.3e, curl = %.3e" % (step, cur_energy, assemble(curl(w.sub(2))*dx)))
    dJ = inner(eps(u_) + outer(v_, v_)/2, eps(phi))*dx \
        + inner(eps(u_) + outer(v_, v_)/2, outer(v_, psi))*dx \
        + (1./12)*inner(grad(v_)-Id, grad(psi))*dx \
        + mu*inner(v_, psi)*dx \
        + mu*inner(v_ - grad(d_), phi)*dx + mu*inner(v_ - grad(d_), grad(eta))*dx

    print("\tSolving...", end='')
    solve(L == -dJ, dw, bc)
    
    # dw is not assigned to a new object so it's ok to reuse du, dd, dv without splitting
    ndu = norm(du)
    ndd = norm(dd)
    ndv = norm(dv)
    
    print(" done with |du| = %.3f, |dd| = %.3f, |dv| = %.3f" % (ndu, ndd, ndv), end='')

    # line search
    new_energy = 0
    alpha = tau
    while True:
        w = project(w_ + alpha*dw, W)
        u, d, v = split(w)
        new_energy = energy(u, d, v)
        #print("New energy: %e, alpha = %.2e" % (new_energy, alpha))
        if new_energy <= cur_energy - omega*alpha*(ndu**2+ndd**2+ndv**2):
            print(", alpha = %e" % alpha)
            history['J'].append(cur_energy)
            history['alpha'].append(alpha)
            cur_energy = new_energy
            break
        if alpha < (1./2)**max_line_steps:
            raise Exception("Line search failed after %d steps" % max_line_steps)
        alpha *= 0.5
    w.rename("disp", "displacement")
    file << (w.split()[0], float(step))
    file << (w.split()[1], float(step))
    
    w_.vector()[:] = w.vector()
    u_, d_, v_ = w_.split()

    step += 1
# Out:
# Step 0, energy = 1.640e+02, curl = -4.283e-18
# 	Solving... done with |du| = 25.824, |dd| = 1799.638, |dv| = 1774.325
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-33ba401a2730> in <module>()
#      91             break
#      92         if alpha < (1./2)**max_line_steps:
# ---> 93             raise Exception("Line search failed after %d steps" % max_line_steps)
#      94         alpha *= 0.5
#      95     w.rename("disp", "displacement")
#
# Exception: Line search failed after 30 steps
